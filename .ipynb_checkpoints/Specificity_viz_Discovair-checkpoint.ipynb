# %%
import scanpy as sc
import os
import warnings
import anndata
import pandas as pd
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt
from scanpy.metrics.specificity.plot import marker_genes_distribution, one_v_max_genelist
import numpy as np
from scanpy.metrics.specificity.get_data import get_average_celltype_counts

# %%
# init functions
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

def find_max_celltype(gene,adata,partition_key="CellType"):
    get_average_celltype_counts(adata , partition_key = partition_key)
    gene_index = int(np.where(adata.var.index == gene)[0])
    max_celltype_index = np.argmax(adata.varm['ave_celltype_counts_CellType'][gene_index,:])
    max_celltype = list(adata.obs['CellType'].cat.categories)[max_celltype_index]
    return(max_celltype)
def show_spec_gene(change):
    output_gene.clear_output()
    with output_gene :
        max_celltype = find_max_celltype(gene=change.new,adata=adata,partition_key="CellType")
        print('Specificity prediction : ' + str(specs.loc[change.new,'spe_type']) )
        print('Most represented celltype, predicted from specificity : ' + max_celltype )

        print('\n Discovair marker information :\n' + str(df_markers_aw.loc[change.new]))
        
        marker_genes_distribution(adata=adata,
                                  gene_list=[change.new],
                                  celltype=max_celltype,
                                  partition_key='CellType')
        one_v_max_genelist(adata=adata,
                           gene_list=[change.new],
                           partition_key='CellType')
        sc.pl.umap(adata=adata, color=change.new, color_map = 'jet')
def show_spec_distrib(change):
    output_marker.clear_output()
    with output_marker :
        spec_markers=markers[change.new].dropna()
        found_markers=spec_markers[spec_markers.isin(adata.var_names)]
        not_found=spec_markers[~spec_markers.isin(adata.var_names)]
        if not not_found.empty:
            print('Gene(s) not found : ' + ','.join(not_found))
        print(specs.loc[found_markers,'spe_type'])
        marker_genes_distribution(adata=adata,
                                  gene_list=spec_markers,
                                  celltype=change.new,
                                  partition_key='CellType')
        one_v_max_genelist(adata=adata,
                           gene_list=spec_markers,
                           partition_key='CellType')
        sc.pl.umap(adata=adata, color=found_markers, color_map = 'jet')

# %% [markdown]
# ## Load data HCA Barbry

# %%
DATA_PATH = '/mnt/d/cellmetrics/'

# %%
count_file = 'HCA_Barbry_Grch38_Raw_filter_Norm.h5ad'
adata = anndata.read_h5ad(DATA_PATH + count_file)

# %%
adata.obs['CellType'].cat.categories
# Out:
# Index(['AT1', 'AT2', 'B cells', 'Basal', 'Brush cells', 'Cycling Basal',
#        'Dendritic', 'Deuterosomal', 'Endothelial', 'Fibroblast', 'Ionocyte',
#        'LT/NK', 'Macrophage', 'Mast cells', 'Monocyte', 'Multiciliated',
#        'Multiciliated N', 'PNEC', 'Pericyte', 'Plasma cells', 'Precursor',
#        'SMG Goblet', 'Secretory', 'Secretory N', 'Serous', 'Smooth muscle',
#        'Suprabasal', 'Suprabasal N'],
#       dtype='object')

# %%
specs = pd.read_csv(DATA_PATH + 'genes_spec_pred_V1', index_col = 'gene')

# %% [markdown]
# ## Load marker tables

# %%
df_markers_aw = pd.read_csv(DATA_PATH + 'SCRINSHOT_Airwaywall_probeset.csv', index_col = 'gene')
df_markers_aw = df_markers_aw[df_markers_aw['selection'] == True]
df_markers_aw.drop('Unnamed: 0',1)
# Out:
#          selection_ranking  selection  AW/Par  pca_gene  \
# gene
# HLA-DRA                  1       True  shared      True
# AREG                     1       True  shared      True
# IFITM1                   1       True  shared      True
# CST3                     1       True  shared      True
# S100A4                   1       True  shared      True
# S100A9                   1       True  shared      True
# VIM                      1       True  shared      True
# MT1A                     1       True  shared      True
# TPSAB1                   1       True  shared      True
# IGFBP7                   1       True  shared      True
# RNASE1                   1       True  shared      True
# CXCR4                    1       True  shared      True
# RPS17                    1       True  shared      True
# FOS                      1       True  shared      True
# GNLY                     1       True  shared      True
# TPSB2                    1       True  shared      True
# APOE                     1       True  shared      True
# CALD1                    2       True  shared     False
# CYB5A                    2       True  shared     False
# S100A2                   2       True  shared     False
# CYP2F1                   2       True  shared     False
# PBK                      2       True  shared     False
# CFD                      2       True  shared     False
# FHOD3                    2       True      AW     False
# CDC20B                   2       True      AW     False
# NREP                     2       True  shared     False
# MMRN1                    2       True  shared     False
# CAPS                     2       True  shared     False
# PLD5                     2       True      AW     False
# RGS5                     2       True  shared     False
# DCN                      2       True  shared     False
# ACAN                     2       True      AW     False
# ZG16B                    2       True      AW     False
# VWF                      2       True  shared     False
# MKI67                    2       True  shared     False
# LCN2                     2       True      AW     False
# LTF                      2       True      AW     False
# TAGLN                    2       True  shared     False
# TFF3                     2       True  shared     False
# MUC5B                    2       True      AW     False
# MUC5AC                   2       True      AW     False
# FOSB                     2       True  shared     False
# IL7R                     3       True  shared      True
# KRT15                    3       True      AW     False
# RGCC                     3       True  shared      True
# SRGN                     3       True  shared      True
# LGALS1                   3       True  shared      True
# RPS29                    3       True  shared      True
# HSPA1A                   3       True  shared      True
# MT-ATP8                  3       True  shared      True
#
#                                                  tree_gene  \
# gene
# HLA-DRA  Myeloid,Mast cells,Pericytes,Deuterosomal,Muco...
# AREG                                       Club,Mast cells
# IFITM1            (Vascular) Endothelial cell,Lymphatic EC
# CST3                       Lymphocyte,Myeloid,Chondrocytes
# S100A4           (Vascular) Endothelial cell,Basal,Myeloid
# S100A9                                             Myeloid
# VIM                                Basal,Club,Lymphatic EC
# MT1A                                             Pericytes
# TPSAB1                                          Mast cells
# IGFBP7      Lymphatic EC,Myeloid,Pericytes,Duct SMG,Goblet
# RNASE1   (Vascular) Endothelial cell,Basal,Club,Lymphoc...
# CXCR4                                Lymphocyte,Mast cells
# RPS17                                                 Club
# FOS                                                  Basal
# GNLY                                            Lymphocyte
# TPSB2                                           Mast cells
# APOE                                     Myeloid,Pericytes
# CALD1                              Pericytes,Smooth muscle
# CYB5A                                      Club,Mucous SMG
# S100A2   Basal,Lymphocyte,Multiciliated,Fibroblast (col...
# CYP2F1                                                none
# PBK                                                   none
# CFD                                 Fibroblast (collapsed)
# FHOD3                                                 none
# CDC20B                                        Deuterosomal
# NREP                                                  none
# MMRN1                                         Lymphatic EC
# CAPS                                  Multiciliated,Goblet
# PLD5                                                  none
# RGS5                                                  none
# DCN                                 Fibroblast (collapsed)
# ACAN                                          Chondrocytes
# ZG16B                                  Duct SMG,Serous SMG
# VWF                       (Vascular) Endothelial cell,Club
# MKI67                                                 none
# LCN2                            Duct SMG,Goblet,Serous SMG
# LTF                             Duct SMG,Goblet,Serous SMG
# TAGLN                              Pericytes,Smooth muscle
# TFF3     (Vascular) Endothelial cell,Basal,Lymphatic EC...
# MUC5B                                  Duct SMG,Mucous SMG
# MUC5AC                                                none
# FOSB                     Fibroblast (collapsed),Mucous SMG
# IL7R                           (Vascular) Endothelial cell
# KRT15                                           Serous SMG
# RGCC                  Smooth muscle,Fibroblast (collapsed)
# SRGN                  Multiciliated,Fibroblast (collapsed)
# LGALS1                                                Club
# RPS29                          Multiciliated,Smooth muscle
# HSPA1A                                        Deuterosomal
# MT-ATP8                                      Multiciliated
#
#                  list_marker                                     marker
# gene
# HLA-DRA                 none                                    Myeloid
# AREG                    none                                 Mast cells
# IFITM1                  none                (Vascular) Endothelial cell
# CST3                    none                       Chondrocytes,Myeloid
# S100A4                  none                                    Myeloid
# S100A9                  none                                    Myeloid
# VIM                     none                               Lymphatic EC
# MT1A                    none                                  Pericytes
# TPSAB1                  none                                 Mast cells
# IGFBP7                  none                     Lymphatic EC,Pericytes
# RNASE1                  none  (Vascular) Endothelial cell,Club,Duct SMG
# CXCR4                   none                                 Lymphocyte
# RPS17                   none                                       Club
# FOS                     none                                      Basal
# GNLY                    none                                 Lymphocyte
# TPSB2                   none                                 Mast cells
# APOE                    none                          Myeloid,Pericytes
# CALD1                   none                    Pericytes,Smooth muscle
# CYB5A                   none                                       Club
# S100A2                  none                                      Basal
# CYP2F1                  Club                                       Club
# PBK                  Cycling                                    Cycling
# CFD                     none                     Fibroblast (collapsed)
# FHOD3     Myoepithelial cell                         Myoepithelial cell
# CDC20B                  none                               Deuterosomal
# NREP     Undefined rare cell                        Undefined rare cell
# MMRN1                   none                               Lymphatic EC
# CAPS                    none                              Multiciliated
# PLD5      Myoepithelial cell                         Myoepithelial cell
# RGS5               Pericytes                                  Pericytes
# DCN                     none                     Fibroblast (collapsed)
# ACAN                    none                               Chondrocytes
# ZG16B                   none                        Duct SMG,Serous SMG
# VWF                     none                (Vascular) Endothelial cell
# MKI67                Cycling                                    Cycling
# LCN2                    none                 Duct SMG,Goblet,Serous SMG
# LTF                     none                        Duct SMG,Serous SMG
# TAGLN                   none                    Pericytes,Smooth muscle
# TFF3                    none             Goblet,Lymphatic EC,Mucous SMG
# MUC5B                   none                        Duct SMG,Mucous SMG
# MUC5AC                Goblet                                     Goblet
# FOSB                    none                                 Mucous SMG
# IL7R                    none                                       none
# KRT15                   none                                       none
# RGCC                    none                                       none
# SRGN                    none                                       none
# LGALS1                  none                                       none
# RPS29                   none                                       none
# HSPA1A                  none                                       none
# MT-ATP8                 none                                       none

# %%
df_markers_par = pd.read_csv(DATA_PATH + 'SCRINSHOT_Parenchyma_probeset.csv', index_col = 'gene')
df_markers_par = df_markers_par[df_markers_par['selection'] == True]
df_markers_par.drop('Unnamed: 0',1)
# Out:
#           selection_ranking  selection  AW/Par  pca_gene  \
# gene
# IL7R                      1       True  shared      True
# S100A4                    1       True  shared      True
# S100A9                    1       True  shared      True
# MT1A                      1       True  shared      True
# IFITM1                    1       True  shared      True
# CXCR4                     1       True  shared      True
# HLA-DRA                   1       True  shared      True
# FOS                       1       True  shared      True
# TIMP1                     1       True  shared      True
# VIM                       1       True  shared      True
# AREG                      1       True  shared      True
# CST3                      1       True  shared      True
# TPSB2                     1       True  shared      True
# RPS17                     1       True  shared      True
# GNLY                      1       True  shared      True
# APOE                      1       True  shared      True
# RNASE1                    1       True  shared      True
# TPSAB1                    1       True  shared      True
# IGFBP7                    1       True  shared      True
# RGCC                      1       True  shared      True
# MKI67                     2       True  shared     False
# NREP                      2       True  shared     False
# FBLN1                     2       True     Par     False
# DCN                       2       True  shared     False
# RGS5                      2       True  shared     False
# S100A2                    2       True  shared     False
# CALD1                     2       True  shared     False
# MMRN1                     2       True  shared     False
# GPX3                      2       True     Par     False
# VWF                       2       True  shared     False
# ADIRF                     2       True     Par     False
# CYB5A                     2       True  shared     False
# CLDN5                     2       True     Par     False
# NAPSA                     2       True     Par     False
# MGP                       2       True     Par     False
# TFF3                      2       True  shared     False
# PBK                       2       True  shared     False
# AGER                      2       True     Par     False
# CYP2F1                    2       True  shared     False
# TAGLN                     2       True  shared     False
# CLU                       2       True     Par     False
# CAPS                      2       True  shared     False
# CFD                       2       True  shared     False
# HLA-DRB1                  3       True  shared      True
# SRGN                      3       True  shared      True
# MT-ATP8                   3       True  shared      True
# BTG1                      3       True     Par      True
# LGALS1                    3       True  shared      True
# RPS29                     3       True  shared      True
#
#                                                   tree_gene  \
# gene
# IL7R      (Vascular) Endothelial cell,Cappillary (G) end...
# S100A4    (Vascular) Endothelial cell,Basal,Myeloid,Capp...
# S100A9                                              Myeloid
# MT1A                                              Pericytes
# IFITM1             (Vascular) Endothelial cell,Lymphatic EC
# CXCR4                                 Lymphocyte,Mast cells
# HLA-DRA                        Myeloid,Mast cells,Pericytes
# FOS                                                   Basal
# TIMP1               Adventitial Fibroblast,Mesothelial cell
# VIM       Basal,Club,Lymphatic EC,AT1,Cappillary (G) end...
# AREG                                        Club,Mast cells
# CST3      Lymphocyte,Myeloid,Cappillary Aerocyte endothe...
# TPSB2                                            Mast cells
# RPS17                                                  Club
# GNLY                                             Lymphocyte
# APOE                                      Myeloid,Pericytes
# RNASE1    (Vascular) Endothelial cell,Basal,Club,Lymphocyte
# TPSAB1                                           Mast cells
# IGFBP7    Lymphatic EC,Myeloid,Pericytes,Cappillary (G) ...
# RGCC      Smooth muscle,Adventitial Fibroblast,AT2,Cappi...
# MKI67                                                  none
# NREP                                                   none
# FBLN1                Adventitial Fibroblast,Lipofibroblasts
# DCN                  Adventitial Fibroblast,Lipofibroblasts
# RGS5                                                   none
# S100A2                       Basal,Lymphocyte,Multiciliated
# CALD1                               Pericytes,Smooth muscle
# MMRN1          Lymphatic EC,Cappillary (G) endothelial cell
# GPX3                   Cappillary Aerocyte endothelial cell
# VWF       (Vascular) Endothelial cell,Club,Cappillary (G...
# ADIRF     Cappillary Aerocyte endothelial cell,Mesotheli...
# CYB5A                                          Club,AT1,AT2
# CLDN5     Cappillary (G) endothelial cell,Cappillary Aer...
# NAPSA                                               AT1,AT2
# MGP                  Adventitial Fibroblast,Lipofibroblasts
# TFF3      (Vascular) Endothelial cell,Basal,Lymphatic EC...
# PBK                                                    none
# AGER                                                AT1,AT2
# CYP2F1                                                 none
# TAGLN                               Pericytes,Smooth muscle
# CLU                                        Mesothelial cell
# CAPS                                          Multiciliated
# CFD                                         Lipofibroblasts
# HLA-DRB1                                    Lipofibroblasts
# SRGN                                  Multiciliated,AT1,AT2
# MT-ATP8                                       Multiciliated
# BTG1                                                    AT1
# LGALS1                                                 Club
# RPS29                           Multiciliated,Smooth muscle
#
#                   list_marker  \
# gene
# IL7R                     none
# S100A4                   none
# S100A9                   none
# MT1A                     none
# IFITM1                   none
# CXCR4                    none
# HLA-DRA                  none
# FOS                      none
# TIMP1                    none
# VIM                      none
# AREG                     none
# CST3                     none
# TPSB2                    none
# RPS17                    none
# GNLY                     none
# APOE                     none
# RNASE1                   none
# TPSAB1                   none
# IGFBP7                   none
# RGCC                     none
# MKI67                 Cycling
# NREP      Undefined rare cell
# FBLN1                    none
# DCN                      none
# RGS5                Pericytes
# S100A2                   none
# CALD1                    none
# MMRN1                    none
# GPX3                     none
# VWF                      none
# ADIRF                    none
# CYB5A                    none
# CLDN5                    none
# NAPSA                    none
# MGP                      none
# TFF3                     none
# PBK                   Cycling
# AGER                     none
# CYP2F1                   Club
# TAGLN                    none
# CLU                      none
# CAPS                     none
# CFD                      none
# HLA-DRB1                 none
# SRGN                     none
# MT-ATP8                  none
# BTG1                     none
# LGALS1                   none
# RPS29                    none
#
#                                                      marker
# gene
# IL7R                        Cappillary (G) endothelial cell
# S100A4                                              Myeloid
# S100A9                                              Myeloid
# MT1A                                              Pericytes
# IFITM1                          (Vascular) Endothelial cell
# CXCR4                                            Lymphocyte
# HLA-DRA                                             Myeloid
# FOS                                                   Basal
# TIMP1               Adventitial Fibroblast,Mesothelial cell
# VIM                                            Lymphatic EC
# AREG                                             Mast cells
# CST3                                                Myeloid
# TPSB2                                            Mast cells
# RPS17                                                  Club
# GNLY                                             Lymphocyte
# APOE                                      Myeloid,Pericytes
# RNASE1                     (Vascular) Endothelial cell,Club
# TPSAB1                                           Mast cells
# IGFBP7                               Lymphatic EC,Pericytes
# RGCC        Cappillary (G) endothelial cell,Lipofibroblasts
# MKI67                                               Cycling
# NREP                                    Undefined rare cell
# FBLN1                Adventitial Fibroblast,Lipofibroblasts
# DCN                  Adventitial Fibroblast,Lipofibroblasts
# RGS5                                              Pericytes
# S100A2                                                Basal
# CALD1                               Pericytes,Smooth muscle
# MMRN1                                          Lymphatic EC
# GPX3                   Cappillary Aerocyte endothelial cell
# VWF       (Vascular) Endothelial cell,Cappillary (G) end...
# ADIRF     Cappillary Aerocyte endothelial cell,Mesotheli...
# CYB5A                                          AT1,AT2,Club
# CLDN5     Cappillary (G) endothelial cell,Cappillary Aer...
# NAPSA                                               AT1,AT2
# MGP                  Adventitial Fibroblast,Lipofibroblasts
# TFF3                                           Lymphatic EC
# PBK                                                 Cycling
# AGER                                                    AT1
# CYP2F1                                                 Club
# TAGLN                               Pericytes,Smooth muscle
# CLU                                        Mesothelial cell
# CAPS                                          Multiciliated
# CFD                                         Lipofibroblasts
# HLA-DRB1                                               none
# SRGN                                                   none
# MT-ATP8                                                none
# BTG1                                                   none
# LGALS1                                                 none
# RPS29                                                  none

# %% [markdown]
# # Display Prediction on marker from Airway wall

# %% [markdown]
# Specificity prediction are in 5 categories : equirep low multirep high unique

# %%
combobox_genes = widgets.Combobox(
    options=list(df_markers_aw.index),
    placeholder='Type a gene',
    description='Gene:',
    ensure_option=True,
    disabled=False,
)
output_gene=widgets.Output()
combobox_genes.observe(show_spec_gene,names='value')
display(combobox_genes)
display(output_gene)
# Out:
# Combobox(value='', description='Gene:', ensure_option=True, options=('HLA-DRA', 'AREG', 'IFITM1', 'CST3', 'S10…
# Output()

# %% [markdown]
# # Display Prediction on marker from Parenchyma

# %%
combobox_genes = widgets.Combobox(
    options=list(df_markers_par.index),
    placeholder='Type a gene',
    description='Gene:',
    ensure_option=True,
    disabled=False,
)
output_gene=widgets.Output()
combobox_genes.observe(show_spec_gene,names='value')
display(combobox_genes)
display(output_gene)
# Out:
# Combobox(value='', description='Gene:', ensure_option=True, options=('IL7R', 'S100A4', 'S100A9', 'MT1A', 'IFIT…
# Output()

# %% [markdown]
# ### Save specificity prediction in a table

# %%
# Find airway wall marker gene not in our dataset
print("Marker genes not present in dataset :",df_markers_aw.index.difference(specs.index))
# Out:
# Marker genes not present in dataset : Index(['ACAN', 'MT-ATP8', 'PLD5', 'RPS17', 'RPS29'], dtype='object', name='gene')

# %%
list_markers = [x for x in df_markers_aw.index if x in specs.index]
df_markers_aw.loc[list_markers,"Specificity_Barbry"] = specs.loc[list_markers,"spe_type"]
list_celltype = [find_max_celltype(gene,adata,partition_key="CellType") for gene in list_markers]
df_markers_aw.loc[list_markers,"Cell_type_Spe_Barbry"] = list_celltype

# %%
# Find parenchyma marker gene not in our dataset
print("Marker genes not present in dataset :",df_markers_par.index.difference(specs.index))
# Out:
# Marker genes not present in dataset : Index(['MT-ATP8', 'NAPSA', 'RPS17', 'RPS29'], dtype='object', name='gene')

# %%
list_markers = [x for x in df_markers_par.index if x in specs.index]
df_markers_par.loc[list_markers,"Specificity_Barbry"] = specs.loc[list_markers,"spe_type"]
list_celltype = [find_max_celltype(gene,adata,partition_key="CellType") for gene in list_markers]
df_markers_par.loc[list_markers,"Cell_type_Spe_Barbry"] = list_celltype

# %% [markdown]
# ## Load data HCA Meyer

# %%
df_meyer = pd.read_csv(DATA_PATH + 'Gene_Meyer_Barbry_comparison.txt', sep='\t', index_col = 'Genes')

# %%
list_markers = [x for x in df_markers_aw.index if x in df_meyer.index]
list_spe = list(df_meyer.loc[list_markers,"spe_type_Meyer"])
df_markers_aw.drop('Unnamed: 0',1)
df_markers_aw.loc[list_markers,"Spqdqzecificity_Meyer"] = list_spe
#df_markers_aw.loc[list_markers,"Ceqzdll_type_Spe"] = df_meyer.loc[list_markers,"CellType"]
df_markers_aw.to_csv(DATA_PATH + 'SCRINSHOT_Airwaywall_probeset_specificity.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-249-c4abc38125d9> in <module>
#       2 list_spe = list(df_meyer.loc[list_markers,"spe_type_Meyer"])
#       3 df_markers_aw.drop('Unnamed: 0',1)
# ----> 4 df_markers_aw.loc[list_markers,"Spqdqzecificity_Meyer"] = list_spe
#       5 #df_markers_aw.loc[list_markers,"Ceqzdll_type_Spe"] = df_meyer.loc[list_markers,"CellType"]
#       6 df_markers_aw.to_csv(DATA_PATH + 'SCRINSHOT_Airwaywall_probeset_specificity.csv')
#
# ~/miniconda3/envs/celltype/lib/python3.8/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     690
#     691         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 692         iloc._setitem_with_indexer(indexer, value, self.name)
#     693
#     694     def _validate_key(self, key, axis: int):
#
# ~/miniconda3/envs/celltype/lib/python3.8/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1633         if take_split_path:
#    1634             # We have to operate column-wise
# -> 1635             self._setitem_with_indexer_split_path(indexer, value, name)
#    1636         else:
#    1637             self._setitem_single_block(indexer, value, name)
#
# ~/miniconda3/envs/celltype/lib/python3.8/site-packages/pandas/core/indexing.py in _setitem_with_indexer_split_path(self, indexer, value, name)
#    1686                     return self._setitem_with_indexer((pi, info_axis[0]), value[0])
#    1687
# -> 1688                 raise ValueError(
#    1689                     "Must have equal len keys and value "
#    1690                     "when setting with an iterable"
#
# ValueError: Must have equal len keys and value when setting with an iterable

# %%
list_markers = [x for x in df_markers_par.index if x in df_meyer.index]
#df_markers_par.loc[list_markers,"Specificity_Meyer"] = df_meyer.loc[list_markers,"spe_type_Meyer"]
#df_markers_par.loc[list_markers,"Cell_type_Spe"] = df_meyer.loc[list_markers,"CellType"]
df_markers_par.to_csv(DATA_PATH + 'SCRINSHOT_Parenchyma_probeset_specificity.csv')
